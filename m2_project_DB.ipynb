# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('housing.csv')

# %%
sns.scatterplot(data=df, x='Landsize', y='Price', hue='Type')
plt.show()

# %%
dfBuilt = df.groupby('YearBuilt').agg({'Price': 'mean'}).sort_values(by = 'YearBuilt', ascending = True).reset_index()
#fig, ax = plt.subplots(figsize=(16, 8))
sns.lineplot(data=dfBuilt, x='YearBuilt', y='Price')
plt.show()

# %%
dfRegion = df.groupby('Regionname').agg({'Price': 'mean'}).sort_values(by = 'Regionname', ascending = True).reset_index()
fig, ax = plt.subplots(figsize=(20, 8))
sns.barplot(data=dfRegion, x='Regionname', y='Price')
plt.show()

# %%
sns.histplot(data=df, x='Price')
plt.show()

# %%
sns.boxplot(data=df, x='YearBuilt', y='Regionname', orient='h')
plt.show()
